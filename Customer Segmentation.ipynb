# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

import seaborn as sns

# %%
df_raw=pd.read_csv('C:/Users/swati/Desktop/prasoon/Data science classes/capstone project/OnlineRetail1.csv',encoding='unicode_escape')
df_raw.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
print(df_raw.shape)
# Out:
# (541909, 8)

# %%
df_raw.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
#Converting Invoice Date to Date Time Format
df_raw['InvoiceDate']=pd.to_datetime(df_raw['InvoiceDate'])

# %%
#Printing Top 5 Rows of the Dataset
df_raw.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df_raw.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
#Checking for NaN Values
df_raw.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
plt.subplots(figsize=(10, 8))
sns.heatmap(df_raw.isnull(), yticklabels = False,cbar = False, cmap='viridis')
plt.show()

# %%
#droping NaN
df_raw.dropna(inplace=True)

# %%
df_raw['Amount']=df_raw['Quantity']*df_raw['UnitPrice']

# %%
df_raw.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Amount
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34

# %%
#Top 10 Countries
df_raw['Country'].value_counts()[:10].plot.bar()
# Out:
# <AxesSubplot:>

# %%
# import pycountry

# COUNTRIES = df_raw['Country'].value_counts().keys().tolist()
# Values= df_raw['Country'].value_counts().values

# # Get all country mappings
# country_mapping = {country.name: country.alpha_2 for country in pycountry.countries}

# # Map your countries
# country_codes = [country_mapping.get(country) for country in COUNTRIES]

# Country_with_value=dict(zip(country_codes,Values))

# Country_with_value.pop(None)

# print(Country_with_value)

# %%
# import pygal
# from pygal.maps.world import COUNTRIES

# worldmap = pygal.maps.world.World()

# worldmap.add('Country',Country_with_value)

# %%
df_raw.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Amount
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34

# %%
#Cohort Analysis
import datetime as dt

def get_month(x): 
    return dt.datetime(x.year, x.month, 1)

df_raw['InvoiceMonth'] = df_raw['InvoiceDate'].apply(get_month)
grouping = df_raw.groupby('CustomerID')['InvoiceMonth']
df_raw['CohortMonth'] = grouping.transform('min')

df_raw.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Amount  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
#
#   InvoiceMonth CohortMonth
# 0   2010-12-01  2010-12-01
# 1   2010-12-01  2010-12-01
# 2   2010-12-01  2010-12-01
# ...

# %%
def get_date_int(df, column):
    year = df[column].dt.year
    month = df[column].dt.month
    day = df[column].dt.day
    return year, month, day

# %%
invoice_year, invoice_month, invoice_day = get_date_int(df_raw, 'InvoiceMonth')
cohort_year, cohort_month, cohort_day = get_date_int(df_raw, 'CohortMonth')

years_diff = invoice_year - cohort_year
months_diff = invoice_month - cohort_month

df_raw['CohortIndex'] = years_diff * 12 + months_diff + 1

df_raw.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Amount  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
#
#   InvoiceMonth CohortMonth  CohortIndex
# 0   2010-12-01  2010-12-01            1
# 1   2010-12-01  2010-12-01            1
# ...

# %%
df_raw['CohortIndex']
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 541904    5
# 541905    5
# 541906    5
# 541907    5
# 541908    5
# Name: CohortIndex, Length: 406829, dtype: int64

# %%
grouping = df_raw.groupby(['CohortMonth', 'CohortIndex'])

cohort_data = grouping['CustomerID'].apply(pd.Series.nunique)

cohort_data = cohort_data.reset_index()

cohort_counts = cohort_data.pivot(index='CohortMonth',
                                 columns='CohortIndex',
                                 values='CustomerID')

# %%
cohort_sizes = cohort_counts.iloc[:,0]
retention = cohort_counts.divide(cohort_sizes, axis=0)
retention.index=retention.index.date

# %%
plt.figure(figsize=(12,10))
plt.title('Retention Rates')

sns.heatmap(data = retention,
           annot = True,
           fmt = '.0%',
           vmin= 0.0,
           vmax=0.5,
           cmap='summer_r')
plt.show()

# %%
df_raw.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Amount  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom   15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom   22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom   20.34
#
#   InvoiceMonth CohortMonth  CohortIndex
# 0   2010-12-01  2010-12-01            1
# 1   2010-12-01  2010-12-01            1
# ...

# %%
# Customer segmentation by 3 important features:
# Recency — Number of days since the last purchase
# Frequency — Number of transactions made over a given period
# Monetary — Amount spent over a given period of time

# %%
# Monetary function
Monetary = df_raw.groupby("CustomerID").Amount.sum()
Monetary = Monetary.reset_index()
Monetary.head(5)
# Out:
#    CustomerID   Amount
# 0     12346.0     0.00
# 1     12347.0  4310.00
# 2     12348.0  1797.24
# 3     12349.0  1757.55
# 4     12350.0   334.40

# %%
# Frequency value
Columns = df_raw[["CustomerID" , "InvoiceNo"]]

k = Columns.groupby("CustomerID").InvoiceNo.count()
Frequency = pd.DataFrame(k)
Frequency = k.reset_index()
Frequency.columns = ["CustomerID" , "Frequency"]
Frequency.head(5)
# Out:
#    CustomerID  Frequency
# 0     12346.0          2
# 1     12347.0        182
# 2     12348.0         31
# 3     12349.0         73
# 4     12350.0         17

# %%
#Merge Amount and Frequency Columns
amount_frequency = Monetary.merge(Frequency,on="CustomerID",how="inner")
amount_frequency.head(5)
# Out:
#    CustomerID   Amount  Frequency
# 0     12346.0     0.00          2
# 1     12347.0  4310.00        182
# 2     12348.0  1797.24         31
# 3     12349.0  1757.55         73
# 4     12350.0   334.40         17

# %%
# Recency value
Recency = df_raw[['CustomerID' ,'InvoiceDate']]
maximum = max(Recency.InvoiceDate)

maximum = maximum + pd.DateOffset(days=1)
Recency['Difference'] = maximum - Recency.InvoiceDate
Recency.head(5)
# Out:
#    CustomerID         InvoiceDate        Difference
# 0     17850.0 2010-12-01 08:26:00 374 days 04:24:00
# 1     17850.0 2010-12-01 08:26:00 374 days 04:24:00
# 2     17850.0 2010-12-01 08:26:00 374 days 04:24:00
# 3     17850.0 2010-12-01 08:26:00 374 days 04:24:00
# 4     17850.0 2010-12-01 08:26:00 374 days 04:24:00

# %%
# Dataframe Merging by Recency
df_Recency = pd.DataFrame(Recency.groupby(['CustomerID','Difference']).min())
df_Recency = df_Recency.reset_index()
df_Recency = df_Recency.drop('InvoiceDate',axis=1)
df_Recency = df_Recency.rename(columns={"Difference" : "Recency"})
df_Recency.head(5)
# Out:
#    CustomerID           Recency
# 0     12346.0 326 days 02:33:00
# 1     12346.0 326 days 02:49:00
# 2     12347.0   2 days 20:58:00
# 3     12347.0  40 days 00:25:00
# 4     12347.0 130 days 04:02:00

# %%
#Combining
RFM = df_Recency.merge(amount_frequency,on='CustomerID')

RFM = RFM.drop("CustomerID",axis=1)
RFM['Recency'] = RFM.Recency.dt.days

# %%
RFM.head()
# Out:
#    Recency  Amount  Frequency
# 0      326     0.0          2
# 1      326     0.0          2
# 2        2  4310.0        182
# 3       40  4310.0        182
# 4      130  4310.0        182

# %%
RFM.shape
# Out:
# (22034, 3)

# %%
#Scaling Data for Clustering
from sklearn.preprocessing import StandardScaler
standard_scaler = StandardScaler()
RFM_Scaled = standard_scaler.fit_transform(RFM)

RFM_Scaled = pd.DataFrame(RFM_Scaled)
RFM_Scaled.columns = ["Frequency" , "Amount" , "Recency"]
RFM_Scaled.head(5)
# Out:
#    Frequency    Amount   Recency
# 0   1.441949 -0.355004 -0.392792
# 1   1.441949 -0.355004 -0.392792
# 2  -1.431975 -0.207249 -0.224985
# 3  -1.094910 -0.207249 -0.224985
# 4  -0.296598 -0.207249 -0.224985

# %%
from sklearn.cluster import KMeans
ine = []
for i in range(1,20):
    km = KMeans(n_clusters=i)
    km.fit(RFM_Scaled)
    ine.append(km.inertia_)

# %%
ks = range(1,20)
plt.figure(figsize=(15,7))
plt.plot(ks, ine[:20], '-o')
plt.xlabel('Number of Clusters, K')
plt.ylabel('Inertia')
plt.xticks(ks)
plt.show()

# %%
km = KMeans(n_clusters=3)
km.fit(RFM_Scaled)

RFM_Scaled['Clusters'] = km.predict(RFM_Scaled)

# %%
RFM_Scaled['Clusters'].value_counts().plot.pie(figsize=(8,8))
plt.legend();
